# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
city_name = ['penang','kedah','johor','KL']
city_pop = [1356342,8765355,4567432,12345675]

# %%
plt.hist(city_pop)
plt.show()

# %%
plt.pie(city_pop,labels=['PNG','KD','JH','KL'])
plt.show()
